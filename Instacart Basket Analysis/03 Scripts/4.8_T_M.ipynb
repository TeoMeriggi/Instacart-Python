# %%
import pandas as pd
import os
import numpy as np

# %%
path = r'/Users/teomeriggi/Documents/Instacart Basket Analysis'

# %%
ords_prods_merge= pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','df_4.7.pkl'))

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
# 5             0           1  Chocolate Sandwich Cookies        61
# 6             0           1  Chocolate Sandwich Cookies        61
# 7             0           1  Chocolate Sandwich Cookies        61
# 8             0           1  Chocolate Sandwich Cookies        61
# 9             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id  order_number  \
# 0             19     5.8          1987   3139998      138            28
# 1             19     5.8          1989   1977647      138            30
# ...

# %%
df.groupby('product_name')

# %%
#performing single aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.562844
# 2                17.518895
# 3                16.907152
# 4                17.537934
# 5                14.894521
# 6                16.658449
# 7                17.072954
# 8                14.942021
# 9                15.447580
# 10               18.681852
# 11               15.352278
# 12               14.327957
# 13               16.578690
# 14               16.666369
# 15               16.153766
# 16               17.768070
# 17               15.602964
# 18               19.674252
# 19               16.924344
# 20               16.292631
# 21               25.535596

# %% [markdown]
# 2.In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.562844
# 2                17.518895
# 3                16.907152
# 4                17.537934
# 5                14.894521
# 6                16.658449
# 7                17.072954
# 8                14.942021
# 9                15.447580
# 10               18.681852
# 11               15.352278
# 12               14.327957
# 13               16.578690
# 14               16.666369
# 15               16.153766
# 16               17.768070
# 17               15.602964
# 18               19.674252
# 19               16.924344
# 20               16.292631
# 21               25.535596

# %% [markdown]
# 3. The results don't differ

# %%
4
ords_prods_merge.groupby('user_id')

# %%
ords_prods_merge['mean_order_number'] = ords_prods_merge.groupby('department_id')['order_number'].transform('mean')

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts (dropna=False)
# Out:
# Regular customer    473041
# Loyal customer      288151
# New customer        238808
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494      New customer             6
# 15     1494      New customer             7
# 16     1494      New customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...

# %%
#Calculate basic statistics of product prices for each loyalty category
loyal_customer_prices = ords_prods_merge.loc[ords_prods_merge['loyalty_flag'] == 'Loyal customer', 'price_range']
regular_customer_prices = ords_prods_merge.loc[ords_prods_merge['loyalty_flag'] == 'Regular customer', 'price_range']
new_customer_prices = ords_prods_merge.loc[ords_prods_merge['loyalty_flag'] == 'New customer', 'price_range']

# %%
loyal_customer_prices.describe()
# Out:
# count                288151
# unique                    3
# top       Mid-range product
# freq                 190410
# Name: price_range, dtype: object

# %%
regular_customer_prices.describe()
# Out:
# count                473041
# unique                    3
# top       Mid-range product
# freq                 312688
# Name: price_range, dtype: object

# %%
new_customer_prices.describe()
# Out:
# count                238808
# unique                    3
# top       Mid-range product
# freq                 156275
# Name: price_range, dtype: object

# %%
6
ords_prods_merge.groupby('user_id')

# %%
ords_prods_merge['mean_price'] = ords_prods_merge.groupby('user_id')['prices'].transform('mean')

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
print (ords_prods_merge)
# Out:
#         Unnamed: 0_x  product_id  \
# 0                  0           1
# 1                  0           1
# 2                  0           1
# 3                  0           1
# 4                  0           1
# ...              ...         ...
# 999995          2029        2029
# 999996          2029        2029
# 999997          2029        2029
# 999998          2029        2029
# 999999          2029        2029
#
#                                         product_name  aisle_id  department_id  \
# 0                         Chocolate Sandwich Cookies        61             19
# 1                         Chocolate Sandwich Cookies        61             19
# 2                         Chocolate Sandwich Cookies        61             19
# 3                         Chocolate Sandwich Cookies        61             19
# 4                         Chocolate Sandwich Cookies        61             19
# ...                                              ...       ...            ...
# ...

# %%
#7 
median_days = ords_prods_merge.groupby('user_id')['days_since_prior_order'].transform('median')
ords_prods_merge['order_frequency_flag'] = np.where(median_days > 20, 'Non-frequent customer',
                                                    np.where(median_days > 10, 'Regular customer', 'Frequent customer'))

# %%
print(ords_prods_merge)
# Out:
#         Unnamed: 0_x  product_id  \
# 0                  0           1
# 1                  0           1
# 2                  0           1
# 3                  0           1
# 4                  0           1
# ...              ...         ...
# 999995          2029        2029
# 999996          2029        2029
# 999997          2029        2029
# 999998          2029        2029
# 999999          2029        2029
#
#                                         product_name  aisle_id  department_id  \
# 0                         Chocolate Sandwich Cookies        61             19
# 1                         Chocolate Sandwich Cookies        61             19
# 2                         Chocolate Sandwich Cookies        61             19
# 3                         Chocolate Sandwich Cookies        61             19
# 4                         Chocolate Sandwich Cookies        61             19
# ...                                              ...       ...            ...
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.8_ords_prods_merge.pkl'))
